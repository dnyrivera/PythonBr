# %% [markdown]
# ## Logic Operators

# %%
a = True 
b = True

if a and b:
    print("Both are true")
else: 
    print("At least one is false")
# Out:
# Both are true

# %%
name = "Donny" 
age = 40 
weight = 100

if (name == 'Donny' and age > 18) and weight < 100:
    print("Login Granted")
else:
    print("Login Denied")
# Out:
# Login Denied
